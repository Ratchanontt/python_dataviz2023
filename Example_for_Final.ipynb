# %% [markdown]
# <a href="https://colab.research.google.com/github/Ratchanontt/python_dataviz2023/blob/main/Example_for_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data From
# https://data.go.th/dataset/covid-19-daily
#
# https://www.youtube.com/watch?v=0PyXrgowm_g

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# เข้า path ที่เราสนใจใน google drive
import os
os.chdir('/content/drive/MyDrive/Data-Viz-2023-2')

# %%
# !ls # เช็คว่ามีไฟล์อะไรบ้างที่อยู่ใน path นั้น
# Out:
#  Bhumjaithai.png			 'table_merge_result (17).gsheet'
#  Compare.csv				 'table_merge_result (18).gsheet'
# 'Copy of table_merge_result (1).gsheet'  'table_merge_result (19).gsheet'
# 'Copy of table_merge_result (2).gsheet'  'table_merge_result (1).gsheet'
# 'Copy of table_merge_result.csv'	 'table_merge_result(1).gsheet'
# 'Copy of table_merge_result.gsheet'	 'table_merge_result (20).gsheet'
#  data_ectre_66.csv			 'table_merge_result (21).gsheet'
# 'DataViz22 Data'			 'table_merge_result (22).gsheet'
#  ectreport2023.xlsx			 'table_merge_result (2).gsheet'
#  iPrice-election.jpg			 'table_merge_result (3).gsheet'
#  max_vote_region.gsheet			 'table_merge_result (4).gsheet'
#  merge_chiangmai.csv			 'table_merge_result (5).gsheet'
#  merge_chiangmai.gsheet			 'table_merge_result (6).gsheet'
#  merge_chiangmai_new.csv		 'table_merge_result (7).gsheet'
#  merge_chiangmai_neww.csv		 'table_merge_result (8).gsheet'
#  merge_chiangmai_neww.gsheet		 'table_merge_result (9).gsheet'
# ...

# %% [markdown]
# # Import Data

# %%
cases = pd.read_excel('/content/drive/MyDrive/DataViz23Data/confirmed-cases-since-120465.xlsx', sheet_name= 'confirmed-cases-since-120465')

# %%
cases.head()
# Out:
#        No. announce_date Notified date   sex age Unit nationality  \
# 0  3905873    2022-04-12    2022-04-11  หญิง  54   ปี    Thailand
# 1  3905874    2022-04-12    2022-04-11  หญิง  36   ปี    Thailand
# 2  3905875    2022-04-12    2022-04-11  หญิง  31   ปี    Thailand
# 3  3905876    2022-04-12    2022-04-11   ชาย  37   ปี    Thailand
# 4  3905877    2022-04-12    2022-04-11  หญิง  33   ปี    Thailand
#
#   province_of_isolation                  risk province_of_onset  \
# 0             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 1             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 2             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
# 3             เชียงใหม่  อยู่ระหว่างการสอบสวน               NaN
# 4             เชียงใหม่  อยู่ระหว่างการสอบสวน         เชียงใหม่
#
#   district_of_onset
# 0            จอมทอง
# 1    เมืองเชียงใหม่
# 2           ดอยหล่อ
# 3       ต่างจังหวัด
# 4            แม่ริม

# %%
cases.shape
# Out:
# (356612, 11)

# %% [markdown]
# # Checking Missing Values

# %%
cases.isnull().all() # เช็คค่าว่าง Null
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
cases.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
cases_notnull = cases.dropna()

# %% [markdown]
# ## Sex Col

# %%
cases[cases['sex'].isnull()] #แสดง row ที่มี sex ว่าง
# Out:
#             No. announce_date Notified date  sex  age Unit nationality  \
# 704     3906577    2022-04-12    2022-04-11  NaN  NaN  NaN    Thailand
# 705     3906578    2022-04-12    2022-04-11  NaN  NaN  NaN    Thailand
# 706     3906579    2022-04-12    2022-04-11  NaN  NaN  NaN    Thailand
# 707     3906580    2022-04-12    2022-04-11  NaN  NaN  NaN    Thailand
# 708     3906581    2022-04-12    2022-04-11  NaN  NaN  NaN    Thailand
# ...         ...           ...           ...  ...  ...  ...         ...
# 353978  4259851    2022-05-01    2022-04-30  NaN   35   ปี         NaN
# 353979  4259852    2022-05-01    2022-04-30  NaN  NaN  NaN         NaN
# 353980  4259853    2022-05-01    2022-04-30  NaN   25   ปี         NaN
# 353981  4259854    2022-05-01    2022-04-30  NaN   25   ปี         NaN
# 353982  4259855    2022-05-01    2022-04-30  NaN   36   ปี         NaN
#
#        province_of_isolation                  risk province_of_onset  \
# ...

# %%
cases[cases['sex'].isnull()].dropna()
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality, province_of_isolation, risk, province_of_onset, district_of_onset]
# Index: []

# %% [markdown]
# ## Age Col

# %%
cases[cases['age'].isnull()] #แสดง row ที่มี age ว่าง
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 21      3905894    2022-04-12    2022-04-11   ชาย  NaN  NaN    Thailand
# 427     3906300    2022-04-12    2022-04-11   ชาย  NaN  NaN    Thailand
# 429     3906302    2022-04-12    2022-04-11  หญิง  NaN  NaN    Thailand
# 549     3906422    2022-04-12    2022-04-11  หญิง  NaN  NaN    Thailand
# 587     3906460    2022-04-12    2022-04-11   ชาย  NaN  NaN    Thailand
# ...         ...           ...           ...   ...  ...  ...         ...
# 356607  4262480    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356608  4262481    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356609  4262482    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356610  4262483    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356611  4262484    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
#
#        province_of_isolation                  risk province_of_onset  \
# ...

# %%
cases[cases['age'].isnull()].dropna()
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality, province_of_isolation, risk, province_of_onset, district_of_onset]
# Index: []

# %% [markdown]
# ## Unit Col

# %%
cases[cases['Unit'].isnull()] #แสดง row ที่มี Unit ว่าง
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 21      3905894    2022-04-12    2022-04-11   ชาย  NaN  NaN    Thailand
# 427     3906300    2022-04-12    2022-04-11   ชาย  NaN  NaN    Thailand
# 429     3906302    2022-04-12    2022-04-11  หญิง  NaN  NaN    Thailand
# 549     3906422    2022-04-12    2022-04-11  หญิง  NaN  NaN    Thailand
# 587     3906460    2022-04-12    2022-04-11   ชาย  NaN  NaN    Thailand
# ...         ...           ...           ...   ...  ...  ...         ...
# 356607  4262480    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356608  4262481    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356609  4262482    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356610  4262483    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356611  4262484    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
#
#        province_of_isolation                  risk province_of_onset  \
# ...

# %%
cases[cases['Unit'].isnull()].dropna()
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality, province_of_isolation, risk, province_of_onset, district_of_onset]
# Index: []

# %% [markdown]
# ## Nationality Col

# %%
cases[cases['nationality'].isnull()] #แสดง row ที่มี nationality ว่าง
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 91      3905964    2022-04-12    2022-04-11   ชาย   69   ปี         NaN
# 92      3905965    2022-04-12    2022-04-11  หญิง   28   ปี         NaN
# 226     3906099    2022-04-12    2022-04-11  หญิง    1   ปี         NaN
# 229     3906102    2022-04-12    2022-04-11   ชาย   13   ปี         NaN
# 231     3906104    2022-04-12    2022-04-11   ชาย   70   ปี         NaN
# ...         ...           ...           ...   ...  ...  ...         ...
# 356607  4262480    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356608  4262481    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356609  4262482    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356610  4262483    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356611  4262484    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
#
#        province_of_isolation                  risk province_of_onset  \
# ...

# %%
cases[cases['nationality'].isnull()].dropna()

# %% [markdown]
# ## province_of_onset Col

# %%
cases[cases['province_of_onset'].isnull()] #แสดง row ที่มี province_of_onset ว่าง
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 3       3905876    2022-04-12    2022-04-11   ชาย   37   ปี    Thailand
# 12      3905885    2022-04-12    2022-04-11  หญิง   28   ปี    Thailand
# 14      3905887    2022-04-12    2022-04-11   ชาย   24   ปี    Thailand
# 22      3905895    2022-04-12    2022-04-11  หญิง   39   ปี    Thailand
# 26      3905899    2022-04-12    2022-04-11  หญิง   26   ปี    Thailand
# ...         ...           ...           ...   ...  ...  ...         ...
# 356607  4262480    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356608  4262481    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356609  4262482    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356610  4262483    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356611  4262484    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
#
#        province_of_isolation                  risk province_of_onset  \
# ...

# %%
cases[cases['province_of_onset'].isnull()].dropna()

# %% [markdown]
# ## District_of_onset Col

# %%
cases[cases['district_of_onset'].isnull()] #แสดง row ที่มี district_of_onset ว่าง
# Out:
#             No. announce_date Notified date   sex  age Unit nationality  \
# 408     3906281    2022-04-12    2022-04-11   ชาย   30   ปี    Thailand
# 409     3906282    2022-04-12    2022-04-11   ชาย   37   ปี    Thailand
# 410     3906283    2022-04-12    2022-04-11   ชาย   59   ปี    Thailand
# 430     3906303    2022-04-12    2022-04-11  หญิง    5   ปี    Thailand
# 431     3906304    2022-04-12    2022-04-11   ชาย   71   ปี    Thailand
# ...         ...           ...           ...   ...  ...  ...         ...
# 356607  4262480    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356608  4262481    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
# 356609  4262482    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356610  4262483    2022-05-01    2022-04-30  หญิง  NaN  NaN         NaN
# 356611  4262484    2022-05-01    2022-04-30   ชาย  NaN  NaN         NaN
#
#        province_of_isolation              risk province_of_onset  \
# ...

# %%
cases[cases['district_of_onset'].isnull()].dropna()

# %% [markdown]
# # Save Table

# %%
import os

# %%
cases.columns
# Out:
# Index(['No.', 'announce_date', 'Notified date', 'sex', 'age', 'Unit',
#        'nationality', 'province_of_isolation', 'risk', 'province_of_onset',
#        'district_of_onset'],
#       dtype='object')

# %%
cases_notnull.to_csv('case_covid.csv', index=False)

# %%
cases_notnull.to_csv(os.path.join('/content/drive/MyDrive/DataViz23Data','case_covid.csv'))
